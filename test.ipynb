# %%
print("Abc")
# !nvidia-smi
# Out:
# Abc
# Mon May  4 10:08:36 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   33C    P0             56W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# !ls
# Out:
# diffIUPAC  sample_data

# %%
# !git clone https://github.com/Lalith2007/diffIUPAC.git
# %cd diffIUPAC
# Out:
# fatal: destination path 'diffIUPAC' already exists and is not an empty directory.
# /content/diffIUPAC

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# ...
# ERROR: Could not find a version that satisfies the requirement rdkit-pypi (from versions: none)
# ERROR: No matching distribution found for rdkit-pypi

# %%
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Skipping torch as it is not installed.
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.4/780.4 MB 3.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 137.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !nvidia-smi
# Out:
# Mon May  4 10:11:53 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   33C    P0             55W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
import torch
print(torch.cuda.is_available())   # should be True
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA A100-SXM4-80GB

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:08
# 🔁 Restarting kernel...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !mamba install -c conda-forge rdkit -y
# Out:
# Looking for: ['rdkit']
#
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch     2%[+] 0.2s
# conda-forge/linux-64   3%
# conda-forge/noarch    24%[+] 0.3s
# conda-forge/linux-64  13%
# conda-forge/noarch    44%[+] 0.4s
# conda-forge/linux-64  18%
# conda-forge/noarch    52%[+] 0.5s
# conda-forge/linux-64  22%
# conda-forge/noarch    86%[+] 0.6s
# conda-forge/linux-64  27%
# conda-forge/noarch    94%[+] 0.7s
# conda-forge/linux-64  27%
# conda-forge/noarch    94%[+] 0.8s
# conda-forge/linux-64  27%
# conda-forge/noarch    94%[+] 0.9s
# conda-forge/linux-64  27%
# conda-forge/noarch    94%conda-forge/noarch
# [+] 1.0s
# conda-forge/linux-64  32%[+] 1.1s
# conda-forge/linux-64  52%[+] 1.2s
# conda-forge/linux-64  72%[+] 1.3s
# conda-forge/linux-64  93%[+] 1.4s
# conda-forge/linux-64  93%[+] 1.5s
# conda-forge/linux-64  93%[+] 1.6s
# conda-forge/linux-64  93%[+] 1.7s
# conda-forge/linux-64  93%[+] 1.8s
# conda-forge/linux-64  93%[+] 1.9s
# ...

# %%
# !mamba install -c conda-forge rdkit python=3.11 -y
# Out:
# Looking for: ['rdkit', 'python=3.11']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# Your pinning does not match what's currently installed. Please remove the pin and fix your installation
#   Pin: python=3.12
#   Currently installed: conda-forge/linux-64::python==3.11.11=h9e4cc4f_1_cpython

# %%
from rdkit import Chem
print("RDKit working ✅")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3090/4099029209.py in <cell line: 0>()
# ----> 1 from rdkit import Chem
#       2 print("RDKit working ✅")
#
# ModuleNotFoundError: No module named 'rdkit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !mamba remove -n base rdkit -y
# !mamba install -c conda-forge rdkit python=3.11 -y
# Out:
# Removing specs: ['rdkit']
# Transaction
#
#   Prefix: /usr/local
#
#   Failure: packages to remove not found in the environment:
#
#   - rdkit
#
# The following packages are missing from the target environment:
#   - rdkit
#
#
# PackagesNotFoundError: The following packages are missing from the target environment:
#   - rdkit
#
#
#
# Looking for: ['rdkit', 'python=3.11']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# Your pinning does not match what's currently installed. Please remove the pin and fix your installation
#   Pin: python=3.12
#   Currently installed: conda-forge/linux-64::python==3.11.11=h9e4cc4f_1_cpython

# %%
from rdkit import Chem
print("RDKit working ✅")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3090/4099029209.py in <cell line: 0>()
# ----> 1 from rdkit import Chem
#       2 print("RDKit working ✅")
#
# ModuleNotFoundError: No module named 'rdkit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# install conda
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !git clone https://github.com/Lalith2007/diffIUPAC.git
# %cd diffIUPAC
# Out:
# fatal: destination path 'diffIUPAC' already exists and is not an empty directory.
# /content/diffIUPAC

# %%
# !ls
# Out:
# api			query.md	    sm_generation.html
# condacolab_install.log	requirements.txt    src
# configs			run_training.py     test.ipynb
# EDM.pdf			scripts		    training.log
# final_dataset.json	small_molecule.pdf
# frontend		sm_generation.docx

# %%
# install rdkit properly
# !mamba install -c conda-forge rdkit python=3.11 -y

# remove bad dependency
# !sed -i '/rdkit-pypi/d' requirements.txt

# install rest
# !pip install -r requirements.txt
# Out:
# Looking for: ['rdkit', 'python=3.11']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# Your pinning does not match what's currently installed. Please remove the pin and fix your installation
#   Pin: python=3.12
#   Currently installed: conda-forge/linux-64::python==3.11.11=h9e4cc4f_1_cpython
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.6/530.6 MB 95.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 MB 112.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 MB 132.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 MB 134.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 139.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.2/188.2 MB 69.9 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !sed -i 's/total_mem/total_memory/g' run_training.py

# %%
# !grep -n total_memory run_training.py
# Out:
# 346:            f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB"

# %%
# !python run_training.py --phase ABC
# Out:
# 2026-05-04 10:36:14,398 INFO [run_training] Loaded config from configs/default.yaml
# 2026-05-04 10:36:14,526 INFO [run_training] Device: cuda
# 2026-05-04 10:36:14,543 INFO [run_training] GPU: NVIDIA A100-SXM4-80GB
# 2026-05-04 10:36:14,543 INFO [run_training] VRAM: 85.1 GB
# 2026-05-04 10:36:14,592 INFO [run_training] Model built: 2,666,670 parameters
# 2026-05-04 10:36:15,093 INFO [src.data.dataset] Affinity filter [-13.0, -6.0]: kept 54189/54189 pairs across 11134 proteins (removed 0)
# 2026-05-04 10:36:15,124 INFO [src.data.dataset] Split: train=43127 pairs (8907 proteins), val=5595 pairs (1113 proteins), test=5467 pairs (1114 proteins)
# 2026-05-04 10:36:15,240 INFO [run_training] Datasets ready: train=43127, val=5595, test=5467
# 2026-05-04 10:36:15,240 INFO [run_training] Contrastive pairs available: 6719 proteins with ≥2 ligands
# 2026-05-04 10:36:15,252 INFO [run_training] No previous checkpoints found for Phase A. Starting fresh.
# ...
